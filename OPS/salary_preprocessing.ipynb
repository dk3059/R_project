# %%
import scrapy
import requests
from scrapy.http import TextResponse  # xpath 연습
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./datas/pulled_salary_data.csv')

# %%
names = list(df[df.시즌 == 2018]['이름'].unique())

# %% [markdown]
# ### 2019년 연봉 크롤링

# %%
data1 = []
for name in names:
    url = "http://www.statiz.co.kr/player.php?opt=11&name={}".format(name)
    req = requests.get(url)
    response = TextResponse(req.url, body=req.text, encoding='utf-8')

    a = response.xpath(
        '/html/body/div/div[1]/div/section[2]/div/div[2]/div/div/div/div[2]/table/tr/td[1]/text()').extract()

    i = len(a) + 1

    season = response.xpath(
        '/html/body/div/div[1]/div/section[2]/div/div[2]/div/div/div/div[2]/table/tr[{}]/td[1]/text()'.format(i)).extract()[0]

    salary = response.xpath(
        '/html/body/div/div[1]/div/section[2]/div/div[2]/div/div/div/div[2]/table/tr[{}]/td[2]/text()'.format(i)).extract()[0]

    data1.append({'이름': name, '시즌': season, '연봉': salary})
    print(season)
# Out:
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019

# %%
data1 = pd.DataFrame(data1)

# %%
data1.to_csv('./datas/sal_2019', index=False)

# %%
df = pd.read_csv('Data/name.csv')
sal = pd.read_csv('Data/salary_stat+kbo.csv')

# %% [markdown]
# ### 계약 크롤링

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 70% !important; }</style>"))
pd.set_option("display.max_columns", 55)
# Out:
# <style>.container { width: 70% !important; }</style>

# %%
data1 = []
for name in df['이름'].unique():
    for i in range(1, 7):
        url = "http://www.statiz.co.kr/player.php?&name={}".format(name)
        req = requests.get(url)
        response = TextResponse(req.url, body=req.text, encoding='utf-8')
        if response.xpath('/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[5]/div/div[2]/table/tr[{}]/td[1]/text()'.format(i)).extract():
            b = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[5]/div/div[2]/table/tr[{}]/td[1]/text()'.format(i)).extract()[0]
            a = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[5]/div/div[2]/table/tr[{}]/td[2]/text()'.format(i)).extract()[0]
            c = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[5]/div/div[2]/table/tr[{}]/td[3]/text()'.format(i)).extract()[0]
        else:
            a = 0
            b = 0
            c = 0
        data1.append({'이름': name, '시즌': b, '계약': a, '참고': c})

    print(name)
# Out:
# 가르시아
# 강귀태
# 강동우
# 강명구
# 강민호
# 강병식
# 강병우
# 강봉규
# 강정호
# 고영민
# 권도영
# 권용관
# 김강
# 김강민
# 김강석
# 김경언
# 김광현
# 김다원
# 김동길
# 김동영
# 김동주
# 김민성
# 김민우
# 김상수
# 김상현
# 김상훈
# 김선빈
# 김연훈
# 김원섭
# 김일경
# 김재우
# 김재현
# 김재호
# 김주찬
# 김준호
# 김지수
# 김태군
# 김태완
# 김현수
# 김형철
# 김회성
# 나주환
# 나지완
# 모창민
# 문규현
# 문선재
# 민병헌
# 박경수
# 박경완
# 박기남
# 박기혁
# 박노민
# 박동원
# 박병호
# 박상현
# 박석민
# 박용근
# 박용택
# 박재상
# 박재홍
# 박정권
# 박정준
# 박정환
# 박종윤
# 박준서
# 박진만
# 박한이
# 배영섭
# 백창수
# 변용선
# 서동욱
# 서성종
# 손시헌
# 손아섭
# 손인호
# 손주인
# 손지환
# 송광민
# 송지만
# 신경현
# 신명철
# 신종길
# 안경현
# 안치용
# 안치홍
# 양의지
# 양종민
# 양준혁
# 오선진
# 오윤
# 오재원
# 오재일
# 오정복
# 오지환
# 오현근
# 용덕한
# 유선정
# 유재웅
# 유한준
# 윤요섭
# 윤진호
# 윤효섭
# 이대수
# 이대형
# 이대호
# 이도형
# 이두환
# 이명기
# 이병규
# 이상훈
# 이성열
# 이성우
# 이성호
# 이숭용
# 이시찬
# 이양기
# 이여상
# 이영수
# 이영우
# 이영욱
# 이용규
# 이우민
# 이원석
# 이인구
# 이재원
# 이정식
# 이종범
# 이종욱
# 이종환
# 이진영
# 이창섭
# 이택근
# 이현곤
# 이호준
# 이희근
# 임익준
# 임재철
# 임한용
# 임훈
# 장민석
# 장성우
# 장성호
# 장영석
# 장종덕
# 장태성
# 전근표
# 전준우
# 전현태
# 정근우
# 정보명
# 정상호
# 정성훈
# 정수빈
# 정수성
# 정원석
# 정주현
# 정현석
# 정형식
# 정훈
# 정희상
# 조동찬
# 조동화
# 조성환
# 조영훈
# 조인성
# 조재호
# 조중근
# ...

# %%
data1
# Out:
# [{'이름': '가르시아', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '가르시아', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '가르시아', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '가르시아', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '가르시아', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '가르시아', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '강귀태', '시즌': '연도', '계약': '종류', '참고': '참고'},
#  {'이름': '강귀태', '시즌': '1998년', '계약': '신인지명', '참고': ' 고졸우선지명(현대)'},
#  {'이름': '강귀태', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '강귀태', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '강귀태', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '강귀태', '시즌': 0, '계약': 0, '참고': 0},
#  {'이름': '강동우', '시즌': '연도', '계약': '종류', '참고': '참고'},
#  {'이름': '강동우', '시즌': '1998년', '계약': '신인지명', '참고': ' 1차지명(삼성)'},
#  {'이름': '강동우', '시즌': '2006년', '계약': '트레이드', '참고': ' 2006-03-29, 삼성 -> 두산'},
#  {'이름': '강동우', '시즌': '2008년', '계약': '트레이드', '참고': ' 2007-11-07, 두산 -> KIA'},
#  {'이름': '강동우', '시즌': '2009년', '계약': '트레이드', '참고': ' 2008-10-20, KIA -> 한화'},
#  {'이름': '강동우',
#   '시즌': '2010년',
#   '계약': 'FA계약',
# ...

# %%
cont = pd.DataFrame(data1)
cont = cont[cont['시즌'] != 0]
cont = cont[cont['시즌'] != '연도']
# Out:
# 7                   고졸우선지명(현대)
# 13                    1차지명(삼성)
# 14        2006-03-29, 삼성 -> 두산
# 15       2007-11-07, 두산 -> KIA
# 16       2008-10-20, KIA -> 한화
#                  ...
# 3751              2차지명 56번(SK)
# 3757              2차지명 30번(SK)
# 3769              2차지명 35번(SK)
# 3775              2차지명 28번(넥센)
# 3799                 1차지명(KIA)
# Name: 참고, Length: 695, dtype: object

# %%
cont[cont['이름'] == '박용택']
# Out:
#       이름     시즌    계약                                                 참고
# 343  박용택  1998년  신인지명                                         고졸우선지명(LG)
# 344  박용택  2011년  FA계약   2010-11-03, LG -> LG , 4년 (340,000만원) … 3년+1년...
# 345  박용택  2015년  FA계약    2014-11-26, LG -> LG , 4년 (500,000만원) / 보상금 0만원
# 346  박용택  2019년  FA계약   2019-01-20, LG -> LG , 2년 (240,000만원) … 1억 / ...

# %%
cont["참고"].apply(lambda data: data.split(
    ",") if len(data.split(",")) > 2 else data)
# Out:
# 7                   고졸우선지명(현대)
# 13                    1차지명(삼성)
# 14        2006-03-29, 삼성 -> 두산
# 15       2007-11-07, 두산 -> KIA
# 16       2008-10-20, KIA -> 한화
#                  ...
# 3751              2차지명 56번(SK)
# 3757              2차지명 30번(SK)
# 3769              2차지명 35번(SK)
# 3775              2차지명 28번(넥센)
# 3799                 1차지명(KIA)
# Name: 참고, Length: 695, dtype: object

# %%
cont['참고'] = cont["참고"].apply(lambda data: data.split(
    ",")[2][1:3] if len(data.split(",")) > 2 else 0)
# Out:
#        이름     시즌    계약 참고
# 7     강귀태  1998년  신인지명  0
# 13    강동우  1998년  신인지명  0
# 14    강동우  2006년  트레이드  0
# 15    강동우  2008년  트레이드  0
# 16    강동우  2009년  트레이드  0
# ...   ...    ...   ... ..
# 3751  최경모  2019년  신인지명  0
# 3757  최민재  2013년  신인지명  0
# 3769  최준우  2018년  신인지명  0
# 3775  추재현  2018년  신인지명  0
# 3799  한준수  2018년  신인지명  0
#
# [695 rows x 4 columns]

# %%
cont = cont[cont['계약'] == 'FA계약']
cont.reset_index(drop=True)
# Out:
#       이름     시즌    계약  참고
# 0    강동우  2010년  FA계약  1년
# 1    강민호  2014년  FA계약  4년
# 2    강민호  2018년  FA계약  4년
# 3    강봉규  2012년  FA계약  2년
# 4    고영민  2016년  FA계약  2년
# ..   ...    ...   ...  ..
# 109  이지영  2020년  FA계약  3년
# 110  송승준  2016년  FA계약  4년
# 111  임창용  2005년  FA계약  2년
# 112  장원준  2015년  FA계약  4년
# 113  김승회  2018년  FA계약  2년
#
# [114 rows x 4 columns]

# %% [markdown]
# ### 이름, 시즌, 계약, 연도 CSV 저장

# %%
cont.to_csv('./Data/cont.csv', index=False)

# %%
list(cont[cont['이름'] == '박용택'])
# Out:
# ['이름', '시즌', '계약', '참고']

# %% [markdown]
# ### MVP 크롤링

# %%
data1 = []
for name in df['이름'].unique():
    for i in range(1, 20):
        url = "http://www.statiz.co.kr/player.php?&name={}".format(name)
        req = requests.get(url)
        response = TextResponse(req.url, body=req.text, encoding='utf-8')
        if response.xpath('/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[2]/td[{}]/b/text()'.format(i)).extract():
            a = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[2]/td[{}]/b/text()'.format(i)).extract()[0]

            b = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[1]/td[{}]/text()'.format(i)).extract()[0]

        else:
            a = 0
            b = 0
        data1.append({'이름': name, '시즌': b, 'MVP': a})
    print(name)
# Out:
# 가르시아
# 강귀태
# 강동우
# 강명구
# 강민호
# 강병식
# 강병우
# 강봉규
# 강정호
# 고영민
# 권도영
# 권용관
# 김강
# 김강민
# 김강석
# 김경언
# 김광현
# 김다원
# 김동길
# 김동영
# 김동주
# 김민성
# 김민우
# 김상수
# 김상현
# 김상훈
# 김선빈
# 김연훈
# 김원섭
# 김일경
# 김재우
# 김재현
# 김재호
# 김주찬
# 김준호
# 김지수
# 김태군
# 김태완
# 김현수
# 김형철
# 김회성
# 나주환
# 나지완
# 모창민
# 문규현
# 문선재
# 민병헌
# 박경수
# 박경완
# 박기남
# 박기혁
# 박노민
# 박동원
# 박병호
# 박상현
# 박석민
# 박용근
# 박용택
# 박재상
# 박재홍
# 박정권
# 박정준
# 박정환
# 박종윤
# 박준서
# 박진만
# 박한이
# 배영섭
# 백창수
# 변용선
# 서동욱
# 서성종
# 손시헌
# 손아섭
# 손인호
# 손주인
# 손지환
# 송광민
# 송지만
# 신경현
# 신명철
# 신종길
# 안경현
# 안치용
# 안치홍
# 양의지
# 양종민
# 양준혁
# 오선진
# 오윤
# 오재원
# 오재일
# 오정복
# 오지환
# 오현근
# 용덕한
# 유선정
# 유재웅
# 유한준
# 윤요섭
# 윤진호
# 윤효섭
# 이대수
# 이대형
# 이대호
# 이도형
# 이두환
# 이명기
# 이병규
# 이상훈
# 이성열
# 이성우
# 이성호
# 이숭용
# 이시찬
# 이양기
# 이여상
# 이영수
# 이영우
# 이영욱
# 이용규
# 이우민
# 이원석
# 이인구
# 이재원
# 이정식
# 이종범
# 이종욱
# 이종환
# 이진영
# 이창섭
# 이택근
# 이현곤
# 이호준
# 이희근
# 임익준
# 임재철
# 임한용
# 임훈
# 장민석
# 장성우
# 장성호
# 장영석
# 장종덕
# 장태성
# 전근표
# 전준우
# 전현태
# 정근우
# 정보명
# 정상호
# 정성훈
# 정수빈
# 정수성
# 정원석
# 정주현
# 정현석
# 정형식
# 정훈
# 정희상
# 조동찬
# 조동화
# 조성환
# 조영훈
# 조인성
# 조재호
# 조중근
# ...

# %%
mvp = pd.DataFrame(data1)
mvp.drop_duplicates()
# Out:
#           이름 시즌 MVP
# 0       가르시아  0   0
# 19       강귀태  0   0
# 38       강동우  0   0
# 57       강명구  0   0
# 76       강민호  0   0
# ...      ... ..  ..
# 11970     터커  0   0
# 11989    페게로  0   0
# 12008  페르난데스  0   0
# 12027    한준수  0   0
# 12046  해즐베이커  0   0
#
# [641 rows x 3 columns]

# %%
mvp = pd.read_csv('./Data/mvp')
mvp = mvp[mvp['시즌'] != 0]

# %%
mvp.to_csv('./Data/mvp1', index=False)

# %% [markdown]
# ### 시즌별 수상

# %%
data1 = []
for name in df['이름'].unique()[398:]:
    for i in range(1, 20):
        url = "http://www.statiz.co.kr/player.php?&name={}".format(name)
        req = requests.get(url)
        response = TextResponse(req.url, body=req.text, encoding='utf-8')
        if response.xpath('/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[2]/td[{}]/text()'.format(i)):
            a = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[2]/td[{}]/text()'.format(i)).extract()[0]
        else:
            a = 0
        if response.xpath('/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[1]/td[{}]/text()'.format(i)):
            b = response.xpath(
                '/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[4]/div/div[2]/table/tr[1]/td[{}]/text()'.format(i)).extract()[0]
        else:
            b = 0
        data1.append({'이름': name, '시즌': b, '수상': a})
    print(name)

# %%
df.to_csv('./Data/prize5.csv', index=False)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 100% !important; }</style>"))
pd.set_option("display.max_columns", 55)
# Out:
# <style>.container { width: 100% !important; }</style>

# %%
df = pd.read_csv('Data/datas0402.csv')

# %%
year = pd.read_csv('./year_start_cont.csv')
year.head()
# Out:
#     이름    데뷔      학력                                 계약
# 0  테임즈  2014  용병-용병대                             ['연도']
# 1  이대호  2001     경남고  ['연도', '2001년', '2012년', '2017년']
# 2  강정호  2006    광주일고                    ['연도', '2006년']
# 3  강정호  2006    광주일고                    ['연도', '2006년']
# 4  박석민  2004     대구고  ['연도', '2004년', '2016년', '2020년']

# %%
prize = pd.read_csv('./Data/Prize.csv')
prize.head()
# Out:
#    Unnamed: 0   이름    시즌  수상
# 0           0  테임즈        수상
# 1           1  테임즈  2014   0
# 2           2  테임즈  2015  GG
# 3           3  테임즈  2016  GG
# 4           4  테임즈     0   0

# %%
prize['시즌'] = prize['시즌'].apply(lambda x: 0 if len(x) < 4 else x)

# %%
prize['시즌'] = prize['시즌'].astype(int)

# %%
prize = pd.DataFrame(prize)

# %%
year = year[year['데뷔'] != 0]

# %%
df = pd.merge(df, year, on='이름', how='inner')

# %%
df1 = pd.merge(df, prize, on=['이름', '시즌'], how='outer')

# %%
df1 = df1.dropna(thresh=6, axis=0)

# %%
del df1['Unnamed: 0']

# %%
df = df.drop_duplicates()
df
# Out:
#        ID   이름    시즌   팀 포지션  나이      G     타석     타수     득점     안타     타1  \
# 0       0  테임즈  2014  NC  1B  29  125.0  514.0  443.0   95.0  152.0   79.0
# 3       0  테임즈  2015  NC  1B  30  142.0  595.0  472.0  130.0  180.0   86.0
# 6       0  테임즈  2016  NC  1B  31  123.0  529.0  436.0  118.0  140.0   67.0
# 9       1  이대호  2010  롯데  3B  29  127.0  552.0  478.0   99.0  174.0  117.0
# 14      1  이대호  2011  롯데  1B  30  133.0  570.0  493.0   76.0  176.0  122.0
# ...   ...  ...   ...  ..  ..  ..    ...    ...    ...    ...    ...    ...
# 3004  234  조동화  2015  SK  CF  35  119.0  304.0  245.0   38.0   64.0   55.0
# 3011  234  조동화  2016  SK  RF  36   76.0  172.0  143.0   24.0   34.0   29.0
# 3018  258  강귀태  2011  넥센   C  33   33.0   89.0   81.0    4.0   19.0   13.0
# 3021  306  이영우  2010  한화  DH  38   12.0   21.0   21.0    0.0    2.0    2.0
# 3022  379  박기혁  2010  롯데  SS  30   48.0  166.0  153.0   10.0   33.0   30.0
#
# ...

# %%
df4[df4['이름'] == '이대호']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f5fb459c6070> in <module>
# ----> 1 df4[df4['이름'] == '이대호']
#
# NameError: name 'df4' is not defined

# %%
mvp = pd.read_csv('./Data/mvp1.csv')
mvp.head()
# Out:
#     이름    시즌    MVP
# 0  박경완  2000  시즌MVP
# 1  이대호  2010  시즌MVP
# 2  이종범  1994  시즌MVP
# 3  김재환  2018  시즌MVP
# 4  서건창  2014  시즌MVP

# %%
df2 = pd.merge(df1, mvp, on=['이름', '시즌'], how='outer')

# %%
df2 = df2.dropna(thresh=6, axis=0)

# %%
df2 = df2.drop_duplicates()

# %%
df2['MVP'] = df2['MVP'].fillna(0)

# %%
df2['MVP'][df2['MVP'] != 0] = 1

# %%
df2.MVP.unique()
# Out:
# array([0, 1], dtype=object)

# %%
df2.수상.unique()
# Out:
# array(['0', 'GG', 'POMVP', 'ALMVP', 'SPMVP', 'HSMVP', nan], dtype=object)

# %%
df2 = df2.dropna(thresh=5, axis=0)

# %%
cont = pd.read_csv('./Data/cont.csv')

# %%
cont.참고 = cont['참고'].apply(lambda x: x[:-1])

# %%
cont = cont[cont.참고 != '']

# %%
cont['시즌'] = cont['시즌'].apply(lambda x: int(x[:-1]))

# %%
cont.head()
# Out:
#     이름    시즌    계약 참고
# 0  강동우  2010  FA계약  1
# 1  강민호  2014  FA계약  4
# 2  강민호  2018  FA계약  4
# 3  강봉규  2012  FA계약  2
# 4  고영민  2016  FA계약  2

# %%
df3 = pd.merge(df2, cont, on=['이름', '시즌'], how='outer')
df3
# Out:
#       ID   이름    시즌    팀  포지션    나이      G     타석     타수     득점     안타     타1  \
# 0    0.0  테임즈  2014   NC   1B  29.0  125.0  514.0  443.0   95.0  152.0   79.0
# 1    0.0  테임즈  2015   NC   1B  30.0  142.0  595.0  472.0  130.0  180.0   86.0
# 2    0.0  테임즈  2016   NC   1B  31.0  123.0  529.0  436.0  118.0  140.0   67.0
# 3    1.0  이대호  2010   롯데   3B  29.0  127.0  552.0  478.0   99.0  174.0  117.0
# 4    1.0  이대호  2011   롯데   1B  30.0  133.0  570.0  493.0   76.0  176.0  122.0
# ..   ...  ...   ...  ...  ...   ...    ...    ...    ...    ...    ...    ...
# 431  NaN  이지영  2020  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 432  NaN  송승준  2016  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 433  NaN  임창용  2005  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 434  NaN  장원준  2015  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 435  NaN  김승회  2018  NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
df3['용병'] = None

# %%
df3['용병'][df3['학력'] == '용병-용병대'] = 1
df3['용병'][df3['학력'] != '용병-용병대'] = 0
df3.용병.unique()
# Out:
# array([1, 0], dtype=object)

# %%
pd.read_csv('./datas/rank.csv', encoding='euc-kr')
# Out:
#     순위    팀    시즌
# 0    1   SK  2010
# 1    2   삼성  2010
# 2    3   두산  2010
# 3    4   롯데  2010
# 4    5  KIA  2010
# ..  ..  ...   ...
# 87   6   kt  2019
# 88   7  KIA  2019
# 89   8   삼성  2019
# 90   9   한화  2019
# 91  10   롯데  2019
#
# [92 rows x 3 columns]

# %%
df3 = df3.dropna(thresh=5, axis=0)
df3.reset_index(drop=True)
# Out:
#         ID   이름    시즌   팀 포지션    나이      G     타석     타수     득점     안타     타1  \
# 0      0.0  테임즈  2014  NC  1B  29.0  125.0  514.0  443.0   95.0  152.0   79.0
# 1      0.0  테임즈  2015  NC  1B  30.0  142.0  595.0  472.0  130.0  180.0   86.0
# 2      0.0  테임즈  2016  NC  1B  31.0  123.0  529.0  436.0  118.0  140.0   67.0
# 3      1.0  이대호  2010  롯데  3B  29.0  127.0  552.0  478.0   99.0  174.0  117.0
# 4      1.0  이대호  2011  롯데  1B  30.0  133.0  570.0  493.0   76.0  176.0  122.0
# ..     ...  ...   ...  ..  ..   ...    ...    ...    ...    ...    ...    ...
# 371  234.0  조동화  2015  SK  CF  35.0  119.0  304.0  245.0   38.0   64.0   55.0
# 372  234.0  조동화  2016  SK  RF  36.0   76.0  172.0  143.0   24.0   34.0   29.0
# 373  258.0  강귀태  2011  넥센   C  33.0   33.0   89.0   81.0    4.0   19.0   13.0
# 374  306.0  이영우  2010  한화  DH  38.0   12.0   21.0   21.0    0.0    2.0    2.0
# 375  379.0  박기혁  2010  롯데  SS  30.0   48.0  166.0  153.0   10.0   33.0   30.0
#
# ...

# %%
df3['참고'] = df3['참고'].fillna(0)
df3.head()
# Out:
#     ID   이름    시즌   팀 포지션    나이      G     타석     타수     득점     안타     타1  \
# 0  0.0  테임즈  2014  NC  1B  29.0  125.0  514.0  443.0   95.0  152.0   79.0
# 1  0.0  테임즈  2015  NC  1B  30.0  142.0  595.0  472.0  130.0  180.0   86.0
# 2  0.0  테임즈  2016  NC  1B  31.0  123.0  529.0  436.0  118.0  140.0   67.0
# 3  1.0  이대호  2010  롯데  3B  29.0  127.0  552.0  478.0   99.0  174.0  117.0
# 4  1.0  이대호  2011  롯데  1B  30.0  133.0  570.0  493.0   76.0  176.0  122.0
#
#      타2   타3    홈런     루타     타점    도루   도실     볼넷    사구    고4     삼진    병살  \
# 0  30.0  6.0  37.0  305.0  121.0  11.0  2.0   58.0   7.0   5.0   99.0   6.0
# 1  42.0  5.0  47.0  373.0  140.0  40.0  8.0  103.0  13.0  11.0   91.0   7.0
# 2  30.0  3.0  40.0  296.0  121.0  13.0  4.0   74.0  12.0   6.0  103.0   2.0
# 3  13.0  0.0  44.0  319.0  133.0   0.0  2.0   61.0  10.0   6.0   77.0  15.0
# 4  26.0  1.0  27.0  285.0  113.0   2.0  0.0   63.0   8.0   8.0   60.0  22.0
#
# ...

# %%
df3.참고 = df3.참고.astype(int)

# %%
for name in df3['이름'].unique():
    temp_df = df3[df3['이름'] == name]
    last = list(temp_df.index)[-1]
    idxs = list(temp_df[temp_df["계약_y"] == "FA계약"]["참고"].index)
    num = list(temp_df[temp_df["계약_y"] == "FA계약"]["참고"])
    idxs_ls = []
    for i in range(len(idxs)):
        for j in range(idxs[i] + 1, idxs[i] + num[i]):
            if j > last:
                break
            idxs_ls.append(j)

    df3['계약_y'].loc[idxs_ls] = '계약중'

# %%
df3[df3['이름'] == '김주찬']
# Out:
#        ID   이름    시즌    팀 포지션    나이      G     타석     타수    득점     안타     타1  \
# 203  65.0  김주찬  2010   롯데  1B  30.0  118.0  535.0  485.0  89.0  134.0  103.0
# 204  65.0  김주찬  2011   롯데  LF  31.0   86.0  371.0  321.0  58.0  100.0   79.0
# 205  65.0  김주찬  2012   롯데  LF  32.0  118.0  488.0  435.0  62.0  128.0   93.0
# 206  65.0  김주찬  2013  KIA  LF  33.0   47.0  195.0  168.0  24.0   51.0   38.0
# 207  65.0  김주찬  2014  KIA  LF  34.0  100.0  442.0  399.0  72.0  138.0   93.0
# 208  65.0  김주찬  2015  KIA  DH  35.0   98.0  377.0  333.0  66.0  109.0   66.0
# 209  65.0  김주찬  2016  KIA  LF  36.0  130.0  555.0  511.0  97.0  177.0  114.0
# 210  65.0  김주찬  2017  KIA  1B  37.0  122.0  478.0  440.0  78.0  136.0   83.0
# 211  65.0  김주찬  2018  KIA  1B  38.0  121.0  471.0  429.0  71.0  146.0  105.0
#
#        타2   타3    홈런     루타     타점    도루    도실    볼넷    사구   고4    삼진    병살  \
# 203  18.0  4.0   9.0  187.0   40.0  65.0  19.0  31.0   5.0  1.0  65.0   5.0
# ...

# %%
df3.to_csv('test_0407.csv', index=False)

# %%
#data = data[data['학력']!=0]

# %%
d['횟수'] = 1
for id_x in d.ID.unique():
    d["횟수"].loc[d[d["ID"] == id_x].reset_index()["index"]] = list(
        d[d["ID"] == id_x].reset_index().reset_index()["level_0"] + 1)

# %%
d['횟수'].loc[d[d['ID'] == 0].reset_index()['index']] = [1, 2, 3]
d
# Out:
#       ID   이름          생일  팀    시즌 포지션  나이      G     타석     타수     득점     안타  \
# 0      0  테임즈  1986-11-10  N  2015  1B  30  142.0  595.0  472.0  130.0  180.0
# 1      1  이대호  1982-06-21  롯  2010  3B  29  127.0  552.0  478.0   99.0  174.0
# 2      2  강정호  1987-04-05  넥  2012  SS  26  124.0  519.0  436.0   77.0  137.0
# 3      2  강정호  1987-04-05  넥  2014  SS  28  117.0  501.0  418.0  103.0  149.0
# 4      2  강정호  1987-04-05  넥  2014  SS  28  117.0  501.0  418.0  103.0  149.0
# ..   ...  ...         ... ..   ...  ..  ..    ...    ...    ...    ...    ...
# 825  170  김동엽  1990-07-24  삼  2019  DH  30   60.0  211.0  195.0   15.0   42.0
# 826  186  지석훈  1984-03-17  N  2016  SS  33  141.0  394.0  351.0   34.0   77.0
# 827  232  박재홍  1973-09-07  S  2011  DH  39   74.0  187.0  161.0   11.0   30.0
# 828  193  박종윤  1982-04-11  롯  2015  1B  34   98.0  326.0  314.0   29.0   80.0
# 829   18  조인성  1975-05-25  한  2016   C  42   76.0  146.0  137.0   10.0   23.0
#
# ...
